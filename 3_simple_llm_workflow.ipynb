# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="llama-3.3-70b-versatile")

# %%
class LLMState(TypedDict):

    prompt : str
    answer: str

# %%
def question(state: LLMState) -> LLMState:
    
    question = state["prompt"]

    answer = model.invoke(question)
    
    answer = answer.content

    state["answer"] = answer

    return state

# %%
graph = StateGraph(LLMState)
graph.add_node(
    "question", question
    )

graph.add_edge(START, "question")
graph.add_edge("question", END)

workflow = graph.compile()

# %%
answer = workflow.invoke({
    "prompt":"who won psl season 11",
})

# %%
answer
# Out:
# {'prompt': 'who won psl season 11',
#  'answer': "I'm not aware of the results of PSL Season 11 as my knowledge cutoff is March 2023. However, I can suggest checking the official Pakistan Super League (PSL) website or other reliable sources for the latest information on the tournament."}
